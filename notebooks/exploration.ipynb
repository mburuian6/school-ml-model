# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
df = pd.read_csv("../input/train.csv")
df.head()
# Out:
#    Insult             Date                                            Comment
# 0       1  20120618192155Z                               "You fuck your dad."
# 1       0  20120528192215Z  "i really don't understand your point.\xa0 It ...
# 2       0              NaN  "A\\xc2\\xa0majority of Canadians can and has ...
# 3       0              NaN  "listen if you dont wanna get married to a man...
# 4       0  20120619094753Z  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...

# %%
len(df)
# Out:
# 3947

# %%
corpus= df["Comment"][:]
corpus[:5]
# Out:
# 0                                 "You fuck your dad."
# 1    "i really don't understand your point.\xa0 It ...
# 2    "A\\xc2\\xa0majority of Canadians can and has ...
# 3    "listen if you dont wanna get married to a man...
# 4    "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
# Name: Comment, dtype: object

# %%
ctv = CountVectorizer()
ctv.fit(corpus)
corpus_ = ctv.transform(corpus)

# %%
print(corpus_)
# Out:
#   (0, 3409)	1
#   (0, 5434)	1
#   (0, 16397)	1
#   (0, 16405)	1
#   (1, 806)	1
#   (1, 938)	1
#   (1, 983)	1
#   (1, 4075)	1
#   (1, 7048)	1
#   (1, 8589)	1
#   (1, 10072)	1
#   (1, 10754)	1
#   (1, 11568)	1
#   (1, 12484)	1
#   (1, 13995)	1
#   (1, 14793)	1
#   (1, 15720)	1
#   (1, 16397)	1
#   (1, 16405)	1
#   (2, 602)	1
#   (2, 750)	1
#   (2, 806)	5
#   (2, 1052)	1
#   (2, 1452)	1
#   (2, 1500)	1
#   :	:
#   (3946, 6088)	1
#   (3946, 6282)	1
#   (3946, 6984)	1
#   (3946, 7048)	1
#   (3946, 7199)	1
#   (3946, 9194)	1
#   (3946, 9613)	1
#   (3946, 9945)	1
#   (3946, 10402)	1
#   (3946, 11308)	1
#   (3946, 11540)	2
#   (3946, 11552)	1
#   (3946, 12612)	1
#   (3946, 12645)	1
#   (3946, 12782)	1
#   (3946, 12799)	1
#   (3946, 13995)	1
#   (3946, 13998)	4
#   (3946, 14062)	1
#   (3946, 14102)	1
#   (3946, 14436)	1
#   (3946, 14911)	1
#   (3946, 15294)	1
#   (3946, 16397)	1
#   (3946, 16405)	1

# %%
print(ctv.vocabulary_)
# Out:
# {'you': 16397, 'fuck': 5434, 'your': 16405, 'dad': 3409, 'really': 11568, 'don': 4075, 'understand': 14793, 'point': 10754, 'xa0': 15720, 'it': 7048, 'seems': 12484, 'that': 13995, 'are': 983, 'mixing': 8589, 'apples': 938, 'and': 806, 'oranges': 10072, 'xc2': 16160, 'xa0majority': 15938, 'of': 9942, 'canadians': 2229, 'can': 2226, 'has': 6080, 'been': 1500, 'wrong': 15619, 'before': 1509, 'now': 9576, 'will': 15462, 'be': 1452, 'again': 602, 'nunless': 9777, 're': 11540, 'supportive': 13647, 'the': 13998, 'idea': 6558, 'nothing': 9565, 'is': 7020, 'full': 5482, 'proof': 11148, 'or': 10070, 'perfect': 10478, 'so': 13022, 'take': 13786, 'chances': 2431, 'if': 6581, 'we': 15294, 'should': 12728, 'inadvertently': 6693, 'kill': 7417, 'son': 13098, 'daughter': 3474, 'then': 14019, 'them': 14016, 'breaks': 1960, 'always': 750, 'regard': 11685, 'as': 1052, 'collateral': 2758, 'damage': 3424, 'like': 7841, 'in': 6690, 'wartime': 15253, 'sorry': 13124, 'but': 2138, 'xa0the': 16081, 'cheques':
# ...

# %%
df.head(20)
# Out:
#     Insult             Date                                            Comment
# 0        1  20120618192155Z                               "You fuck your dad."
# 1        0  20120528192215Z  "i really don't understand your point.\xa0 It ...
# 2        0              NaN  "A\\xc2\\xa0majority of Canadians can and has ...
# 3        0              NaN  "listen if you dont wanna get married to a man...
# 4        0  20120619094753Z  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
# 5        0  20120620171226Z  "@SDL OK, but I would hope they'd sign him to ...
# 6        0  20120503012628Z                      "Yeah and where are you now?"
# 7        1              NaN  "shut the fuck up. you and the rest of your fa...
# 8        1  20120502173553Z  "Either you are fake or extremely stupid...may...
# 9        1  20120620160512Z  "That you are an idiot who understands neither...
# 10       0  20120620015140Z  "@jdstorm dont wish him injury but it happened...
# ...

# %%
df.Comment.head()
# Out:
# 0                                 "You fuck your dad."
# 1    "i really don't understand your point.\xa0 It ...
# 2    "A\\xc2\\xa0majority of Canadians can and has ...
# 3    "listen if you dont wanna get married to a man...
# 4    "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
# Name: Comment, dtype: object

# %%
test = pd.read_csv('../input/test.csv')
test.head()
# Out:
#    id             Date                                            Comment
# 0   1  20120603163526Z                 "like this if you are a tribe fan"
# 1   2  20120531215447Z              "you're idiot......................."
# 2   3  20120823164228Z  "I am a woman Babs, and the only "war on women...
# 3   4  20120826010752Z  "WOW & YOU BENEFITTED SO MANY WINS THIS YEAR F...
# 4   5  20120602223825Z  "haha green me red you now loser whos winning ...

# %%
len(test)
# Out:
# 2235

# %%
merge = pd.concat([df,test])
len(merge)
# Out:
# 6182

# %%
len(df)
# Out:
# 3947

# %%
merge.reset_index(inplace=True)

# %%
merge.tail()
# Out:
#       index  Insult             Date  \
# 6177   2230     NaN  20120528100303Z
# 6178   2231     NaN  20120531185813Z
# 6179   2232     NaN  20120529130822Z
# 6180   2233     NaN  20120531045826Z
# 6181   2234     NaN  20120531184524Z
#
#                                                 Comment      id
# 6177  "FUCKIN LAME COME ON WTF STOP FUCKING OVER MY ...  2231.0
# 6178  "YOU SHUT YOUR IGNORANT PIE HOLE YOU LITTLE IN...  2232.0
# 6179  "sweetie pie is looking very much like her cou...  2233.0
# 6180  "ball4real where are you with your miami g-ayn...  2234.0
# 6181  "Man....if you are a 3 point shooter, you must...  2235.0

# %%
merge.head()
# Out:
#    index  Insult             Date  \
# 0      0     1.0  20120618192155Z
# 1      1     0.0  20120528192215Z
# 2      2     0.0              NaN
# 3      3     0.0              NaN
# 4      4     0.0  20120619094753Z
#
#                                              Comment  id
# 0                               "You fuck your dad." NaN
# 1  "i really don't understand your point.\xa0 It ... NaN
# 2  "A\\xc2\\xa0majority of Canadians can and has ... NaN
# 3  "listen if you dont wanna get married to a man... NaN
# 4  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd... NaN

# %%
merge.to_csv('../input/merged.csv')

# %%
test.tail()
# Out:
#         id             Date                                            Comment
# 2230  2231  20120528100303Z  "FUCKIN LAME COME ON WTF STOP FUCKING OVER MY ...
# 2231  2232  20120531185813Z  "YOU SHUT YOUR IGNORANT PIE HOLE YOU LITTLE IN...
# 2232  2233  20120529130822Z  "sweetie pie is looking very much like her cou...
# 2233  2234  20120531045826Z  "ball4real where are you with your miami g-ayn...
# 2234  2235  20120531184524Z  "Man....if you are a 3 point shooter, you must...

# %%
df.tail()
# Out:
#       Insult             Date  \
# 3942       1  20120502172717Z
# 3943       0  20120528164814Z
# 3944       0  20120620142813Z
# 3945       0  20120528205648Z
# 3946       0  20120515200734Z
#
#                                                 Comment
# 3942  "you are both morons and that is never happening"
# 3943  "Many toolbars include spell check, like Yahoo...
# 3944  "@LambeauOrWrigley\xa0\xa0@K.Moss\xa0\nSioux F...
# 3945  "How about Felix? He is sure turning into one ...
# 3946  "You're all upset, defending this hipster band...

# %%
merge.tail()
# Out:
#       index  Insult             Date  \
# 6177   2230     NaN  20120528100303Z
# 6178   2231     NaN  20120531185813Z
# 6179   2232     NaN  20120529130822Z
# 6180   2233     NaN  20120531045826Z
# 6181   2234     NaN  20120531184524Z
#
#                                                 Comment      id
# 6177  "FUCKIN LAME COME ON WTF STOP FUCKING OVER MY ...  2231.0
# 6178  "YOU SHUT YOUR IGNORANT PIE HOLE YOU LITTLE IN...  2232.0
# 6179  "sweetie pie is looking very much like her cou...  2233.0
# 6180  "ball4real where are you with your miami g-ayn...  2234.0
# 6181  "Man....if you are a 3 point shooter, you must...  2235.0

# %%
test = pd.read_csv('../input/test_with_solutions.csv')
test.head()
# Out:
#    Insult             Date                                            Comment  \
# 0       0              NaN  "THE DRUDGE REPORT\\n\\n\\n\\nYou won't see th...
# 1       0  20120618222256Z  "@ian21\xa0"Roger Clemens is the fucking man, ...
# 2       1  20120618213617Z  "Agree with Alan you are an extremest idiot.  ...
# 3       0              NaN  "Really?\\n\\nI see Marc Lamont Hill on variou...
# 4       0  20120620003825Z  "Really suck isn't the word, when many of our ...
#
#          Usage
# 0   PublicTest
# 1   PublicTest
# 2   PublicTest
# 3  PrivateTest
# 4  PrivateTest

# %%
merged = pd.concat([df,test])
merged.tail()
# Out:
#       Insult             Date  \
# 2642       0  20120612003508Z
# 2643       0  20120619210456Z
# 2644       0  20120528234613Z
# 2645       1  20120619153537Z
# 2646       0  20120620000237Z
#
#                                                 Comment        Usage
# 2642  "Never really gave it much thought. I just fig...  PrivateTest
# 2643                 "Nadie se salva de la regla 34 xd"  PrivateTest
# 2644               "Question: Are you a boy or a girl?"  PrivateTest
# 2645  "Leave your email or phone number and maybe yo...  PrivateTest
# 2646  "From the scenarios you present, I see you bel...  PrivateTest

# %%
merged_ = merged.drop('Usage',axis=1)
merged_.head()
# Out:
#    Insult             Date                                            Comment
# 0       1  20120618192155Z                               "You fuck your dad."
# 1       0  20120528192215Z  "i really don't understand your point.\xa0 It ...
# 2       0              NaN  "A\\xc2\\xa0majority of Canadians can and has ...
# 3       0              NaN  "listen if you dont wanna get married to a man...
# 4       0  20120619094753Z  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...

# %%
merged_.tail()
# Out:
#       Insult             Date  \
# 2642       0  20120612003508Z
# 2643       0  20120619210456Z
# 2644       0  20120528234613Z
# 2645       1  20120619153537Z
# 2646       0  20120620000237Z
#
#                                                 Comment
# 2642  "Never really gave it much thought. I just fig...
# 2643                 "Nadie se salva de la regla 34 xd"
# 2644               "Question: Are you a boy or a girl?"
# 2645  "Leave your email or phone number and maybe yo...
# 2646  "From the scenarios you present, I see you bel...

# %%
merged_.to_csv('../input/merged.csv')
